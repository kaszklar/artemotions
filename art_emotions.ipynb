# %% [markdown]
# ## Met art emotions analysis

# %% [markdown]
# Using the open data from Met art, imported into Microsoft facial emotion recognition.

# %%
import pandas as pd
emotions = pd.read_csv('average_emotions.csv', index_col='Title')
emotions.head()
# Out:
#                                                    Object ID  \
# Title
# Hunter (from McGuire Scrapbook)                        10056
# The Tahitian Chief Otore (from McGuire Scrapbook)      10057
# James McNeill Whistler                                 10064
# The Spanish Girl in Reverie                            10070
# The Stoning of Saint Stephen                           10071
#
#                                                      Artist Display Name  \
# Title
# Hunter (from McGuire Scrapbook)                    William Apthorp Adams
# The Tahitian Chief Otore (from McGuire Scrapbook)    Alfred Thomas Agate
# James McNeill Whistler                              John White Alexander
# The Spanish Girl in Reverie                           Washington Allston
# The Stoning of Saint Stephen                          Washington Allston
#
#                                                   Object Date Classification  \
# Title
# ...

# %%
emotions = emotions.drop(columns="Object ID")
emotions.head()
# Out:
#                                                      Artist Display Name  \
# Title
# Hunter (from McGuire Scrapbook)                    William Apthorp Adams
# The Tahitian Chief Otore (from McGuire Scrapbook)    Alfred Thomas Agate
# James McNeill Whistler                              John White Alexander
# The Spanish Girl in Reverie                           Washington Allston
# The Stoning of Saint Stephen                          Washington Allston
#
#                                                   Object Date Classification  \
# Title
# Hunter (from McGuire Scrapbook)                     1797–1878       Drawings
# The Tahitian Chief Otore (from McGuire Scrapbook)    ca. 1839       Drawings
# James McNeill Whistler                                    NaN       Drawings
# The Spanish Girl in Reverie                              1831      Paintings
# The Stoning of Saint Stephen                              NaN       Drawings
#
# ...

# %%
emotions.dtypes
# Out:
# Artist Display Name     object
# Object Date             object
# Classification          object
# Link Resource           object
# Avg. Anger             float64
# Avg. Contempt          float64
# Avg. Disgust           float64
# Avg. Fear              float64
# Avg. Happiness         float64
# Avg. Neutral           float64
# Avg. Sadness           float64
# Avg. Surprise          float64
# dtype: object

# %%
emotions['Object Date']
# Out:
# Title
# Hunter (from McGuire Scrapbook)                                       1797–1878
# The Tahitian Chief Otore (from McGuire Scrapbook)                      ca. 1839
# James McNeill Whistler                                                      NaN
# The Spanish Girl in Reverie                                                1831
# The Stoning of Saint Stephen                                                NaN
# Maurice Levy                                                           ca. 1820
# Philip Van Cortlandt                                                   ca. 1810
# James Topham Brady                                                         1869
# James Badger                                                               1760
# Elizabeth Humphrey                                                         1899
# Head of a Girl (from McGuire Scrapbook)                                     NaN
# John F. Kensett                                                            1875
# ...

# %%
pattern = r'([0-9]+)'
emotions['Start Date'] = emotions['Object Date'].str.extract(pattern)
emotions
# Out:
#                                                                              Artist Display Name  \
# Title
# Hunter (from McGuire Scrapbook)                                            William Apthorp Adams
# The Tahitian Chief Otore (from McGuire Scrapbook)                            Alfred Thomas Agate
# James McNeill Whistler                                                      John White Alexander
# The Spanish Girl in Reverie                                                   Washington Allston
# The Stoning of Saint Stephen                                                  Washington Allston
# Maurice Levy                                                                           Ezra Ames
# Philip Van Cortlandt                                                                   Ezra Ames
# James Topham Brady                                                         Joseph Alexander Ames
# ...

# %%
missingcrit = emotions['Object Date'] == 0
emotions[missingcrit].size
# Out:
# 0

# %%
emotions.size
# Out:
# 383006

# %% [markdown]
# Roughly a third of the data does not have a "Object Date" value. How to do date analysis here...

# %% [markdown]
# ### Questions to ask:
# Emotions per classification, by decade of date, by artist, most common emotions

# %%
emotions['Start Date'] = pd.to_datetime(emotions['Start Date'], errors='coerce')
emotions.dtypes
# Out:
# Artist Display Name            object
# Object Date                    object
# Classification                 object
# Link Resource                  object
# Avg. Anger                    float64
# Avg. Contempt                 float64
# Avg. Disgust                  float64
# Avg. Fear                     float64
# Avg. Happiness                float64
# Avg. Neutral                  float64
# Avg. Sadness                  float64
# Avg. Surprise                 float64
# Start Date             datetime64[ns]
# dtype: object

# %%
startdate = emotions['Start Date']
startdate.max()
# Out:
# Timestamp('2017-01-01 00:00:00')

# %%
datebins = pd.cut(x = startdate, bins = [1550-01-01, 1600, 1650, 1700, 1750, 1800, 1850, 1900, 1950, 2000, 2050])
datebins.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-123-d20cf23d0b0a> in <module>()
# ----> 1 datebins = pd.cut(x = startdate, bins = [1550, 1600, 1650, 1700, 1750, 1800, 1850, 1900, 1950, 2000, 2050])
#       2 datebins.head()
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/reshape/tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates)
#     224     else:
#     225         bins = np.asarray(bins)
# --> 226         bins = _convert_bin_to_numeric_type(bins, dtype)
#     227         if (np.diff(bins) < 0).any():
#     228             raise ValueError('bins must increase monotonically.')
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/reshape/tile.py in _convert_bin_to_numeric_type(bins, dtype)
#     424             bins = to_datetime(bins).view(np.int64)
#     425         else:
# ...

# %%
angry = emotions['Avg. Anger']
angry_crit = angry > 0.5
emotions[angry_crit].size
# Out:
# 923

# %%
angry = emotions[angry_crit]
angry.head()
# Out:
#                                                     Artist Display Name  \
# Title
# Joseph Jefferson as Dr. Pangloss                    John Singer Sargent
# [Man in Loincloth with Strands of Beads]                        Unknown
# Woman and Baby, Hidalgo                                     Paul Strand
# J. Pierpont Morgan, Esq.                             Edward J. Steichen
# Nikita Balieff of the Chauve Souris, San Francisco      Johan Hagemeyer
#
#                                                               Object Date  \
# Title
# Joseph Jefferson as Dr. Pangloss                                     1890
# [Man in Loincloth with Strands of Beads]                        1860s–70s
# Woman and Baby, Hidalgo                                1933, printed 1940
# J. Pierpont Morgan, Esq.                            1903, printed 1909–10
# Nikita Balieff of the Chauve Souris, San Francisco                   1928
#
# ...

# %%
happy_crit = emotions['Avg. Happiness'] > 0.5
happy = emotions[happy_crit]
happy.size
# Out:
# 52975

# %%
happy.head()
# Out:
#                                                       Artist Display Name  \
# Title
# Child in Green Coat                                          Mary Cassatt
# Carmencita                                          William Merritt Chase
# Roland                                              William Merritt Chase
# Anne Charlotte Lynch (Later Mrs. Vincenzo Botta)  Savinien Edme Dubourjal
# Rosa Bonheur                                                 Anna Klumpke
#
#                                                  Object Date Classification  \
# Title
# Child in Green Coat                                 ca. 1904       Drawings
# Carmencita                                              1890      Paintings
# Roland                                              ca. 1902      Paintings
# Anne Charlotte Lynch (Later Mrs. Vincenzo Botta)    ca. 1847       Drawings
# Rosa Bonheur                                            1898      Paintings
#
# ...

# %%
surprise_crit = emotions['Avg. Surprise'] > 0.5
surprise = emotions[surprise_crit]
surprise.size
# Out:
# 1391

# %%
surprise.head()
# Out:
#                                                    Artist Display Name  \
# Title
# Morning - The Coverlet                               Clarence H. White
# [Mannequin with Long Neck]                                Walker Evans
# [Leila Hill]                                              Walker Evans
# [The Chicken Lady with her Dressed-up Stuffed C...        Walker Evans
# [Boy in Hat and Raincoat]                                 Walker Evans
#
#                                                    Object Date Classification  \
# Title
# Morning - The Coverlet                                    1906    Photographs
# [Mannequin with Long Neck]                             1973–74    Photographs
# [Leila Hill]                                          8-Nov-73    Photographs
# [The Chicken Lady with her Dressed-up Stuffed C...   29-Jun-74    Photographs
# [Boy in Hat and Raincoat]                              1973–74    Photographs
#
# ...

# %%
neutral_crit = emotions['Avg. Neutral'] > 0.5
neutral = emotions[neutral_crit]
neutral.size
# Out:
# 320385

# %%
neutral.head()
# Out:
#                                                      Artist Display Name  \
# Title
# Hunter (from McGuire Scrapbook)                    William Apthorp Adams
# The Tahitian Chief Otore (from McGuire Scrapbook)    Alfred Thomas Agate
# James McNeill Whistler                              John White Alexander
# The Spanish Girl in Reverie                           Washington Allston
# The Stoning of Saint Stephen                          Washington Allston
#
#                                                   Object Date Classification  \
# Title
# Hunter (from McGuire Scrapbook)                     1797–1878       Drawings
# The Tahitian Chief Otore (from McGuire Scrapbook)    ca. 1839       Drawings
# James McNeill Whistler                                    NaN       Drawings
# The Spanish Girl in Reverie                              1831      Paintings
# The Stoning of Saint Stephen                              NaN       Drawings
#
# ...

# %%
sadness_crit = emotions['Avg. Sadness'] > 0.5
sadness = emotions[sadness_crit]
sadness.size
# Out:
# 1755

# %%
sadness.head()
# Out:
#                                   Artist Display Name         Object Date  \
# Title
# Mother and Child                         Mary Cassatt                1906
# Subway Passenger                         Walker Evans  January–March 1938
# Tenement Fire, Harlem                          Weegee                1942
# Soldier's Farewell                             Weegee            ca. 1942
# [A Gypsy Dancing-Girl, Kathiawar]         E. Taurines            ca. 1915
#
#                                   Classification  \
# Title
# Mother and Child                        Drawings
# Subway Passenger                     Photographs
# Tenement Fire, Harlem                Photographs
# Soldier's Farewell                   Photographs
# [A Gypsy Dancing-Girl, Kathiawar]    Photographs
#
#                                                                        Link Resource  \
# Title
# Mother and Child                   http://www.metmuseum.org/art/collection/search...
# ...

# %%
fear_crit = emotions['Avg. Fear'] > 0.5
fear = emotions[fear_crit]
fear.size
# Out:
# 91

# %%
fear.head()
# Out:
#                                                                                   Artist Display Name  \
# Title
# Icono-photographique. Mécanisme de la Physionom...  Guillaume-Benjamin-Amand Duchenne de Boulogne|...
# Electro–Physiologie, Figure 64                      Adrien Tournachon|Guillaume-Benjamin-Amand Duc...
# Spoon Designs                                                         Anonymous, French, 19th century
# Second Scene of Thieves                                                     Louis Léopold Boilly|Gror
# Vito "Babe" Parilli, University of Kentucky, fr...                                 Bowman Gum Company
#
#                                                               Object Date  \
# Title
# Icono-photographique. Mécanisme de la Physionom...  1854–56, printed 1862
# Electro–Physiologie, Figure 64                      1854–56, printed 1862
# Spoon Designs                                                19th century
# ...

# %%
disgust_crit = emotions['Avg. Disgust'] > 0.5
disgust = emotions[disgust_crit]
disgust.size
# Out:
# 13

# %%
disgust.head()
# Out:
#                                                    Artist Display Name  \
# Title
# Card Number 59, Al Wistert, Tackle, Philidelphi...  Bowman Gum Company
#
#                                                    Object Date  \
# Title
# Card Number 59, Al Wistert, Tackle, Philidelphi...        1950
#
#                                                      Classification  \
# Title
# Card Number 59, Al Wistert, Tackle, Philidelphi...  Prints|Ephemera
#
#                                                                                         Link Resource  \
# Title
# Card Number 59, Al Wistert, Tackle, Philidelphi...  http://www.metmuseum.org/art/collection/search...
#
#                                                     Avg. Anger  Avg. Contempt  \
# Title
# Card Number 59, Al Wistert, Tackle, Philidelphi...       0.047          0.015
#
#                                                     Avg. Disgust  Avg. Fear  \
# Title
# ...

# %%
contempt_crit = emotions['Avg. Contempt'] > 0.5
contempt = emotions[contempt_crit]
contempt.size
# Out:
# 78

# %%
contempt
# Out:
#                                                                                   Artist Display Name  \
# Title
# Jan Uytenbogaert (The Gold Weigher)                 Rembrandt (Rembrandt van Rijn)|Captain William...
# Tom Zachary, Boston Braves, from the Goudey Gum...                                 Goudey Gum Company
# Figure 50: Affected weeping and face in repose      Guillaume-Benjamin-Amand Duchenne de Boulogne|...
# Bill Rigney, Infield, New York Giants, from Col...                                 Bowman Gum Company
# Portrait of Matthias Buchinger                      Matthias Buchinger|Anonymous, British, 18th ce...
# A clown standing with one hand on his hip and a...                 José Guadalupe Posada|José Sanchez
#
#                                                               Object Date  \
# Title
# Jan Uytenbogaert (The Gold Weigher)                                  1639
# Tom Zachary, Boston Braves, from the Goudey Gum...                   1933
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline
plt.style.use('seaborn')

# %%
print(plt.style.available)
# Out:
# ['seaborn-dark', 'seaborn-darkgrid', 'seaborn-ticks', 'fivethirtyeight', 'seaborn-whitegrid', 'classic', '_classic_test', 'fast', 'seaborn-talk', 'seaborn-dark-palette', 'seaborn-bright', 'seaborn-pastel', 'grayscale', 'seaborn-notebook', 'ggplot', 'seaborn-colorblind', 'seaborn-muted', 'seaborn', 'Solarize_Light2', 'seaborn-paper', 'bmh', 'tableau-colorblind10', 'seaborn-white', 'dark_background', 'seaborn-poster', 'seaborn-deep']

# %%
neutral_sampledf = neutral_df.sample(frac=0.01)

# %%
neutral_sampledf.plot(x='Start Date', y='Avg. Neutral', kind='bar', figsize=(30, 15))

# %%
happy_sampledf = happy_df.sample(frac=0.05)

# %%
happy_sampledf.plot(x='Start Date', y='Avg. Happiness', kind='bar', figsize=(30, 15))

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot_date('Start Date', 'Avg. Anger', data=angry)

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot_date('Start Date', 'Avg. Contempt', data=contempt)

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot_date('Start Date', 'Avg. Surprise', data=surprise)

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot_date('Start Date', 'Avg. Fear', data=fear)

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot_date('Start Date', 'Avg. Happiness', data=happy)

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot_date('Start Date', 'Avg. Neutral', data=neutral)

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot_date('Start Date', 'Avg. Disgust', data=disgust)

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot_date('Start Date', 'Avg. Sadness', data=sadness)

# %%
pd.to_csv(emotions)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-325-76f515c38f40> in <module>()
# ----> 1 pd.to_csv(emotions)
#
# AttributeError: module 'pandas' has no attribute 'to_csv'
